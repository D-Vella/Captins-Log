# %% [markdown]
# # Recording testing
#
# This is to test the differences in the transcription and recording modules to get the best out of them.

# %%
import sys
import os

sys.path.append(os.path.abspath('..'))

from services.transcriber import transcribe_audio

# %%
print("hello world")
